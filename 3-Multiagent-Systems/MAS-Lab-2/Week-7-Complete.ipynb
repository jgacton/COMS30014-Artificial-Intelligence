# %%
#######################################
# COMS30014 - Artificial Intelligence #
# Multiagent Systems Lab - I          #
# Covid-19 Simulation                 #
#######################################

# Before starting, make sure you have installed Mesa 
# You could install via command line --- pip install mesa
# For generating plots, you will need matplotlib which too you can install via command line --- pip install matplotlib

# %%
NUM_OF_AGENTS = 1000

# PLACES
PARK = 0
HOME = 1
GROCERY = 2
QC = 3 # Quarantine center
VC = 4

# INFECTION STATES
NOT_INFECTED = 0
INFECTED_A = 1
INFECTED_S = 2
CRITICAL = 3
#CURED = 4
DECEASED = 4 # was 5 before

# Capacity of quarantine center
QC_LIMIT = 100 # Capacity of quarantine center
VC_CAP = 10

# %%
from mesa import Agent, Model
from mesa.time import RandomActivation
from mesa.space import MultiGrid
from mesa.datacollection import DataCollector

class HumanAgent(Agent):
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        self.homeId = unique_id//4
        self.health = NOT_INFECTED
        self.vaccinated = 0

    def step(self):
        self.updateHealth()
        self.move()

    # Function for mobility pattern modeling
    
    def move(self):
        x, y = self.pos
        if x==QC:
            return
        if self.model.quarantine and self.model.QC_Occupancy < QC_LIMIT and self.health == CRITICAL:
            self.model.grid.move_agent(self, (QC,0))
            self.model.QC_Occupancy += 1
            return
        if self.model.quarantine and self.model.QC_Occupancy < QC_LIMIT and self.health == INFECTED_S and self.random.uniform(0, 1) <= 0.20:
            self.model.grid.move_agent(self, (QC,0))
            self.model.QC_Occupancy += 1
            return
        if x == HOME:
            p = self.random.uniform(0, 1)
            # Visit park with 10% probability
            if p <= 0.1:
                newX = PARK
                newY = self.random.choice((0,1)) # Visit one of the two parks
          # Visit grocery store with 20% probability
            elif p <= 0.3:
                newX = GROCERY
                newY = self.random.choice((0,1,2,3,4)) # Visit one of the five grocery stores
            elif p <= 0.4 and self.model.V_Today < VC_CAP:
                self.vaccinated = 1
                self.model.V_Today += 1
                newX = x
                newY = y
            else:
                newX = x
                newY = y
        if x == GROCERY or x == PARK: # If grocery or park, return home
            newX = HOME
            newY = self.homeId
        self.model.grid.move_agent(self, (newX,newY))

    # Function for modeling the spread of the virus

    def updateHealth(self):
        p = self.random.uniform(0, 1)
        x,y = self.pos
        alpha = 0.5 if self.vaccinated == 1 else 1
        beta = 2 if x == HOME else 1
        if self.health == INFECTED_A:
            if p<= 0.36*alpha:
                self.health += 1
            elif p<= 0.36*alpha+0.2*beta:
                self.health-=1
        elif self.health == INFECTED_S:
            if p <= 0.01*alpha:
                self.health += 1
            elif p <= 0.01*alpha+0.1*beta:
                self.health = NOT_INFECTED
                x,y = self.pos
                if x == QC:
                    self.model.QC_Occupancy -= 1                
        elif self.health == CRITICAL:
            if p <= 0.05*beta:
                self.health = NOT_INFECTED
                x,y = self.pos
                if x == QC:
                    self.model.QC_Occupancy -= 1
            elif p <= 0.05*beta+0.2*alpha:
                self.health = DECEASED
                self.model.deceasedCount += 1
                x,y = self.pos
                if x == QC:
                    self.model.QC_Occupancy -= 1
        return
    
    def infect(self):
        p = self.random.uniform(0, 1)
        if self.health == NOT_INFECTED and p > self.model.p0b:
                self.health += 1


def compute_infected(model):
    infectedAgents = [agent for agent in model.schedule.agents if agent.health in (INFECTED_A, INFECTED_S, CRITICAL) ]
    return len(infectedAgents)

class CovidModel(Model):
    """A model with some number of agents."""
    def __init__(self, N, startingState, quarantine = False, socialDistancing = False):
        self.num_agents = N
        # self.random.seed(42)
        self.QC_Occupancy = 0
        self.deceasedCount = 0
        self.quarantine = quarantine
        self.grid = MultiGrid(5 if quarantine else 4, 250, False)
        self.schedule = RandomActivation(self)
        self.running = True
        self.V_Today = 0
        self.vaccinated = 0
        
        # With socialdistancing the probability of infection is 10% (p0b = 0.9) otherwise it is 50%
        self.p0b = 0.5
        
        ###########
        # HINT: 
        # You need to update the the next if block to correctly set infection probability when social distancing is TRUE
        # You need to change quarantine center capacity too
        ###########
        if socialDistancing:
            self.p0b = 0.9
        else:
            self.p0b = 0.5
        ###########
        
        # Create agents
        for i in range(self.num_agents):
            a = HumanAgent(i, self)
            self.schedule.add(a)
            self.grid.place_agent(a, (HOME, a.homeId))
        for a in self.random.sample(self.schedule.agents,int(startingState*N)):
            a.health = INFECTED_A
        self.datacollector = DataCollector(
            model_reporters={"Infected": compute_infected,
                             "QC_Occupancy": "QC_Occupancy"}
            )
    def step(self):
        self.vaccinated += self.V_Today
        self.V_Today = 0
        self.datacollector.collect(self)
        '''Advance the model by one step.'''
        self.schedule.step()
        self.identifyAgentsAndUpdateSpread()
    def identifyAgentsAndUpdateSpread(self):
        # Park
        for y in range(2):
            agents = self.grid.get_cell_list_contents([(PARK,y)])
            self.updateSpread(agents)
        # Grocery
        for y in range(5):
            agents = self.grid.get_cell_list_contents([(GROCERY,y)])
            self.updateSpread(agents)
        # Home
        for y in range(250):
            agents = self.grid.get_cell_list_contents([(HOME,y)])
            self.updateSpread(agents)
    def updateSpread(self, agents):
        if any(a.health in (INFECTED_A, INFECTED_S, CRITICAL) for a in agents):
            [a.infect() for a in agents]

# %%
def runSimulation(startingState,quarantine=False,socialDistancing=False):
    modelInst = CovidModel(NUM_OF_AGENTS, startingState, quarantine, socialDistancing)
    i=0
    while any(a.health in (INFECTED_A, INFECTED_S, CRITICAL) for a in modelInst.schedule.agents):
        i += 1
        modelInst.step()
    modelDF = modelInst.datacollector.get_model_vars_dataframe()
    
    return i, modelInst.deceasedCount, modelDF.QC_Occupancy,modelDF.Infected,modelDF.vaccinated

# %% [markdown]
# # Scenario 1a. No Quarantine Centers and No Social Distancing; 10% Infection at Start
# StartingState = 10%
#
# Quarantine=False
#
# Social Distancing=False

# %%
StartingState = 0.1
quarantine=False
socialDistancing=False

averageDays = 0
dayWithMaxInfectionRate = 0
maxInfection = 0
averageCasualties = 0
for i in range(10):
    days, Casualties, QC_Occupancy, Infected, Vaccinated = runSimulation(StartingState,quarantine,socialDistancing)
    averageDays+=days
    dayWithMaxInfectionRate+=Infected.idxmax()
    maxInfection += Infected.max()
    averageCasualties += Casualties
    if i == 9:
        # QC_Occupancy.plot(legend=True)
        Infected.plot(legend=True)
        Vaccinated.plot(legend=True)
print('Average number of days before stabilization: ' + str(averageDays/10))
print('Average of the Day with peak Infection ('+str(maxInfection/10)+'): ' + str(dayWithMaxInfectionRate/10))
print('Average Number of Casualties: ' + str(averageCasualties/10))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/bx/mt7qyk8x4y3cr63zdm0f62j00000gn/T/ipykernel_31390/1920439603.py in ?()
#       6 dayWithMaxInfectionRate = 0
#       7 maxInfection = 0
#       8 averageCasualties = 0
#       9 for i in range(10):
# ---> 10     days, Casualties, QC_Occupancy, Infected, Vaccinated = runSimulation(StartingState,quarantine,socialDistancing)
#      11     averageDays+=days
#      12     dayWithMaxInfectionRate+=Infected.idxmax()
#      13     maxInfection += Infected.max()
#
# /var/folders/bx/mt7qyk8x4y3cr63zdm0f62j00000gn/T/ipykernel_31390/4147200558.py in ?(startingState, quarantine, socialDistancing)
#       5         i += 1
#       6         modelInst.step()
#       7     modelDF = modelInst.datacollector.get_model_vars_dataframe()
#       8
# ----> 9     return i, modelInst.deceasedCount, modelDF.QC_Occupancy,modelDF.Infected,modelDF.vaccinated
#
# ~/opt/anaconda3/envs/ML_Labs/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'vaccinated'

# %% [markdown]
# # Scenario 1b. No Quarantine Centers and No Social Distancing; 25% Infection at Start
# StartingState = 25%
#
# Quarantine=False
#
# Social Distancing=False

# %%
StartingState = 0.25
quarantine=False
socialDistancing=False

averageDays = 0
dayWithMaxInfectionRate = 0
maxInfection = 0
averageCasualties = 0
for i in range(10):
    days, Casualties, QC_Occupancy, Infected = runSimulation(StartingState,quarantine,socialDistancing)
    averageDays+=days
    dayWithMaxInfectionRate+=Infected.idxmax()
    maxInfection += Infected.max()
    averageCasualties += Casualties
    if i == 9:
        # QC_Occupancy.plot(legend=True)
        Infected.plot(legend=True)
print('Average number of days before stabilization: ' + str(averageDays/10))
print('Average of the Day with peak Infection ('+str(maxInfection/10)+'): ' + str(dayWithMaxInfectionRate/10))
print('Average Number of Casualties: ' + str(averageCasualties/10))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/jgacton/Documents/Academia/Undergraduate/Year Three/Artificial Intelligence/Week 8/Lab/Week-7-Complete.ipynb Cell 8 line 1
#       <a href='vscode-notebook-cell:/Users/jgacton/Documents/Academia/Undergraduate/Year%20Three/Artificial%20Intelligence/Week%208/Lab/Week-7-Complete.ipynb#X10sZmlsZQ%3D%3D?line=7'>8</a> averageCasualties = 0
#       <a href='vscode-notebook-cell:/Users/jgacton/Documents/Academia/Undergraduate/Year%20Three/Artificial%20Intelligence/Week%208/Lab/Week-7-Complete.ipynb#X10sZmlsZQ%3D%3D?line=8'>9</a> for i in range(10):
# ---> <a href='vscode-notebook-cell:/Users/jgacton/Documents/Academia/Undergraduate/Year%20Three/Artificial%20Intelligence/Week%208/Lab/Week-7-Complete.ipynb#X10sZmlsZQ%3D%3D?line=9'>10</a>     days, Casualties, QC_Occupancy, Infected = runSimulation(StartingState,quarantine,socialDistancing)
#      <a href='vscode-notebook-cell:/Users/jgacton/Documents/Academia/Undergraduate/Year%20Three/Artificial%20Intelligence/Week%208/Lab/Week-7-Complete.ipynb#X10sZmlsZQ%3D%3D?line=10'>11</a>     averageDays+=days
#      <a href='vscode-notebook-cell:/Users/jgacton/Documents/Academia/Undergraduate/Year%20Three/Artificial%20Intelligence/Week%208/Lab/Week-7-Complete.ipynb#X10sZmlsZQ%3D%3D?line=11'>12</a>     dayWithMaxInfectionRate+=Infected.idxmax()
#
# /Users/jgacton/Documents/Academia/Undergraduate/Year Three/Artificial Intelligence/Week 8/Lab/Week-7-Complete.ipynb Cell 8 line 6
#       <a href='vscode-notebook-cell:/Users/jgacton/Documents/Academia/Undergraduate/Year%20Three/Artificial%20Intelligence/Week%208/Lab/Week-7-Complete.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a> while any(a.health in (INFECTED_A, INFECTED_S, CRITICAL) for a in modelInst.schedule.agents):
#       <a href='vscode-notebook-cell:/Users/jgacton/Documents/Academia/Undergraduate/Year%20Three/Artificial%20Intelligence/Week%208/Lab/Week-7-Complete.ipynb#X10sZmlsZQ%3D%3D?line=4'>5</a>     i += 1
# ----> <a href='vscode-notebook-cell:/Users/jgacton/Documents/Academia/Undergraduate/Year%20Three/Artificial%20Intelligence/Week%208/Lab/Week-7-Complete.ipynb#X10sZmlsZQ%3D%3D?line=5'>6</a>     modelInst.step()
#       <a href='vscode-notebook-cell:/Users/jgacton/Documents/Academia/Undergraduate/Year%20Three/Artificial%20Intelligence/Week%208/Lab/Week-7-Complete.ipynb#X10sZmlsZQ%3D%3D?line=6'>7</a> modelDF = modelInst.datacollector.get_model_vars_dataframe()
#       <a href='vscode-notebook-cell:/Users/jgacton/Documents/Academia/Undergraduate/Year%20Three/Artificial%20Intelligence/Week%208/Lab/Week-7-Complete.ipynb#X10sZmlsZQ%3D%3D?line=8'>9</a> return i, modelInst.deceasedCount, modelDF.QC_Occupancy,modelDF.Infected
#
# /Users/jgacton/Documents/Academia/Undergraduate/Year Three/Artificial Intelligence/Week 8/Lab/Week-7-Complete.ipynb Cell 8 line 1
#     <a href='vscode-notebook-cell:/Users/jgacton/Documents/Academia/Undergraduate/Year%20Three/Artificial%20Intelligence/Week%208/Lab/Week-7-Complete.ipynb#X10sZmlsZQ%3D%3D?line=137'>138</a> '''Advance the model by one step.'''
#     <a href='vscode-notebook-cell:/Users/jgacton/Documents/Academia/Undergraduate/Year%20Three/Artificial%20Intelligence/Week%208/Lab/Week-7-Complete.ipynb#X10sZmlsZQ%3D%3D?line=138'>139</a> self.V_Today = 0
# --> <a href='vscode-notebook-cell:/Users/jgacton/Documents/Academia/Undergraduate/Year%20Three/Artificial%20Intelligence/Week%208/Lab/Week-7-Complete.ipynb#X10sZmlsZQ%3D%3D?line=139'>140</a> self.schedule.step()
#     <a href='vscode-notebook-cell:/Users/jgacton/Documents/Academia/Undergraduate/Year%20Three/Artificial%20Intelligence/Week%208/Lab/Week-7-Complete.ipynb#X10sZmlsZQ%3D%3D?line=140'>141</a> self.identifyAgentsAndUpdateSpread()
#
# File ~/opt/anaconda3/envs/ML_Labs/lib/python3.11/site-packages/mesa/time.py:128, in RandomActivation.step(self)
#     123 def step(self) -> None:
#     124     """Executes the step of all agents, one at a time, in
#     125     random order.
#     126
#     127     """
# --> 128     self.do_each("step", shuffle=True)
#     129     self.steps += 1
#     130     self.time += 1
#
# File ~/opt/anaconda3/envs/ML_Labs/lib/python3.11/site-packages/mesa/time.py:110, in BaseScheduler.do_each(self, method, agent_keys, shuffle)
#     108 for agent_key in agent_keys:
#     109     if agent_key in self._agents:
# --> 110         getattr(self._agents[agent_key], method)()
#
# /Users/jgacton/Documents/Academia/Undergraduate/Year Three/Artificial Intelligence/Week 8/Lab/Week-7-Complete.ipynb Cell 8 line 1
#      <a href='vscode-notebook-cell:/Users/jgacton/Documents/Academia/Undergraduate/Year%20Three/Artificial%20Intelligence/Week%208/Lab/Week-7-Complete.ipynb#X10sZmlsZQ%3D%3D?line=12'>13</a> def step(self):
#      <a href='vscode-notebook-cell:/Users/jgacton/Documents/Academia/Undergraduate/Year%20Three/Artificial%20Intelligence/Week%208/Lab/Week-7-Complete.ipynb#X10sZmlsZQ%3D%3D?line=13'>14</a>     self.updateHealth()
# ---> <a href='vscode-notebook-cell:/Users/jgacton/Documents/Academia/Undergraduate/Year%20Three/Artificial%20Intelligence/Week%208/Lab/Week-7-Complete.ipynb#X10sZmlsZQ%3D%3D?line=14'>15</a>     self.move()
#
# /Users/jgacton/Documents/Academia/Undergraduate/Year Three/Artificial Intelligence/Week 8/Lab/Week-7-Complete.ipynb Cell 8 line 5
#      <a href='vscode-notebook-cell:/Users/jgacton/Documents/Academia/Undergraduate/Year%20Three/Artificial%20Intelligence/Week%208/Lab/Week-7-Complete.ipynb#X10sZmlsZQ%3D%3D?line=49'>50</a>     newX = HOME
#      <a href='vscode-notebook-cell:/Users/jgacton/Documents/Academia/Undergraduate/Year%20Three/Artificial%20Intelligence/Week%208/Lab/Week-7-Complete.ipynb#X10sZmlsZQ%3D%3D?line=50'>51</a>     newY = self.homeId
# ---> <a href='vscode-notebook-cell:/Users/jgacton/Documents/Academia/Undergraduate/Year%20Three/Artificial%20Intelligence/Week%208/Lab/Week-7-Complete.ipynb#X10sZmlsZQ%3D%3D?line=51'>52</a> self.model.grid.move_agent(self, (newX,newY))
#
# File ~/opt/anaconda3/envs/ML_Labs/lib/python3.11/site-packages/mesa/space.py:429, in _Grid.move_agent(self, agent, pos)
#     421 """Move an agent from its current position to a new position.
#     422
#     423 Args:
#    (...)
#     426     pos: Tuple of new position to move the agent to.
#     427 """
#     428 pos = self.torus_adj(pos)
# --> 429 self.remove_agent(agent)
#     430 self.place_agent(agent, pos)
#
# File ~/opt/anaconda3/envs/ML_Labs/lib/python3.11/site-packages/mesa/space.py:552, in MultiGrid.remove_agent(self, agent)
#     550 pos = agent.pos
#     551 x, y = pos
# --> 552 self._grid[x][y].remove(agent)
#     553 if self._empties_built and self.is_cell_empty(pos):
#     554     self._empties.add(pos)
#
# KeyboardInterrupt:

# %% [markdown]
# # Scenario 1c. No Quarantine Centers and No Social Distancing; 50% Infection at Start
# StartingState = 50%
#
# Quarantine=False
#
# Social Distancing=False

# %%
# Add code for baseline 3 here
StartingState = 0.5
quarantine=False
socialDistancing=False

averageDays = 0
dayWithMaxInfectionRate = 0
maxInfection = 0
averageCasualties = 0
for i in range(10):
    days, Casualties, QC_Occupancy, Infected = runSimulation(StartingState,quarantine,socialDistancing)
    averageDays+=days
    dayWithMaxInfectionRate+=Infected.idxmax()
    maxInfection += Infected.max()
    averageCasualties += Casualties
    if i == 9:
        # QC_Occupancy.plot(legend=True)
        Infected.plot(legend=True)
print('Average number of days before stabilization: ' + str(averageDays/10))
print('Average of the Day with peak Infection ('+str(maxInfection/10)+'): ' + str(dayWithMaxInfectionRate/10))
print('Average Number of Casualties: ' + str(averageCasualties/10))
# Out:
# Average number of days before stabilization: 916.4
# Average of the Day with peak Infection (862.4): 10.7
# Average Number of Casualties: 948.6

# %% [markdown]
# # Adding Quarantine Centers
# Enable quarantine centers for each baseline and see how the plots change
# In the line plot, include a plot for capacity of qurantine center too

# %%
# Add code to generate plots with quarantine centers here

# %% [markdown]
# # Scenario 2a. Quarantine Centers; 10% Infection at start)
# StartingState = 10%
#
# Quarantine=True
#
# Social Distancing=False

# %%
StartingState = 0.1
quarantine=True
socialDistancing=False

averageDays = 0
dayWithMaxInfectionRate = 0
maxInfection = 0
averageCasualties = 0
averageMaxCapacityDay = 0
averageMaxCapacity = 0
for i in range(10):
    days, Casualties, QC_Occupancy, Infected = runSimulation(StartingState,quarantine,socialDistancing)
    averageDays+=days
    dayWithMaxInfectionRate+=Infected.idxmax()
    maxInfection += Infected.max()
    averageMaxCapacity += QC_Occupancy.max()
    averageMaxCapacityDay += QC_Occupancy.idxmax()
    averageCasualties += Casualties
    if i == 9:
        QC_Occupancy.plot(legend=True)
        Infected.plot(legend=True)
print('Average number of days before stabilization: ' + str(averageDays/10))
print('Average of the Day with peak Infection ('+str(maxInfection/10)+'): ' + str(dayWithMaxInfectionRate/10))
print('Average Number of Casualties: ' + str(averageCasualties/10))
print('Average of Max Quarantine centre capacity utilized: ' + str(averageMaxCapacity/10))
print('Average of Max Quarantine centre capacity utilized at: ' + str(averageMaxCapacityDay/10))
# Out:
# Average number of days before stabilization: 120.2
# Average of the Day with peak Infection (769.2): 10.0
# Average Number of Casualties: 190.2
# Average of Max Quarantine centre capacity utilized: 100.0
# Average of Max Quarantine centre capacity utilized at: 4.7

# %% [markdown]
# # Scenario 2b. Quarantine Centers; 25% Infection at Start
# StartingState = 25%
#
# Quarantine=True
#
# Social Distancing=False

# %%
StartingState = 0.25
quarantine=True
socialDistancing=False

averageDays = 0
dayWithMaxInfectionRate = 0
maxInfection = 0
averageCasualties = 0
averageMaxCapacityDay = 0
averageMaxCapacity = 0
for i in range(10):
    days, Casualties, QC_Occupancy, Infected = runSimulation(StartingState,quarantine,socialDistancing)
    averageDays+=days
    dayWithMaxInfectionRate+=Infected.idxmax()
    maxInfection += Infected.max()
    averageMaxCapacity += QC_Occupancy.max()
    averageMaxCapacityDay += QC_Occupancy.idxmax()
    averageCasualties += Casualties
    if i == 9:
        QC_Occupancy.plot(legend=True)
        Infected.plot(legend=True)
print('Average number of days before stabilization: ' + str(averageDays/10))
print('Average of the Day with peak Infection ('+str(maxInfection/10)+'): ' + str(dayWithMaxInfectionRate/10))
print('Average Number of Casualties: ' + str(averageCasualties/10))
print('Average of Max Quarantine centre capacity utilized: ' + str(averageMaxCapacity/10))
print('Average of Max Quarantine centre capacity utilized at: ' + str(averageMaxCapacityDay/10))
# Out:
# Average number of days before stabilization: 126.8
# Average of the Day with peak Infection (774.0): 9.1
# Average Number of Casualties: 196.4
# Average of Max Quarantine centre capacity utilized: 100.0
# Average of Max Quarantine centre capacity utilized at: 3.7

# %% [markdown]
# # Scenario 2c. Quarantine Centers; 50% Infection at Start
# StartingState = 50%
#
# Quarantine=True
#
# Social Distancing=False

# %%
StartingState = 0.50
quarantine=True
socialDistancing=False

averageDays = 0
dayWithMaxInfectionRate = 0
maxInfection = 0
averageCasualties = 0
averageMaxCapacityDay = 0
averageMaxCapacity = 0
for i in range(10):
    days, Casualties, QC_Occupancy, Infected = runSimulation(StartingState,quarantine,socialDistancing)
    averageDays+=days
    dayWithMaxInfectionRate+=Infected.idxmax()
    maxInfection += Infected.max()
    averageMaxCapacity += QC_Occupancy.max()
    averageMaxCapacityDay += QC_Occupancy.idxmax()
    averageCasualties += Casualties
    if i == 9:
        QC_Occupancy.plot(legend=True)
        Infected.plot(legend=True)
print('Average number of days before stabilization: ' + str(averageDays/10))
print('Average of the Day with peak Infection ('+str(maxInfection/10)+'): ' + str(dayWithMaxInfectionRate/10))
print('Average Number of Casualties: ' + str(averageCasualties/10))
print('Average of Max Quarantine centre capacity utilized: ' + str(averageMaxCapacity/10))
print('Average of Max Quarantine centre capacity utilized at: ' + str(averageMaxCapacityDay/10))
# Out:
# Average number of days before stabilization: 115.0
# Average of the Day with peak Infection (793.2): 6.1
# Average Number of Casualties: 192.0
# Average of Max Quarantine centre capacity utilized: 100.0
# Average of Max Quarantine centre capacity utilized at: 2.9

# %% [markdown]
# # Enabling Social Distancing Norms
# Enable social distancing norms in addition to quaratine centers for each baseline and see how the plots change
# In the line plot, include a plot for capacity of qurantine center too

# %%
# Add code to generate plots with social distancing and quarantine centers here

# %% [markdown]
# # Scenario 3a. Enforcing Social Distancing Norms; 10% Infection at Start
# StartingState = 10%
#
# Quarantine=True
#
# Social Distancing=True

# %%
StartingState = 0.10
quarantine=True
socialDistancing=True

averageDays = 0
dayWithMaxInfectionRate = 0
maxInfection = 0
averageCasualties = 0
averageMaxCapacity = 0
averageMaxCapacityDay = 0
for i in range(10):
    days, Casualties, QC_Occupancy, Infected = runSimulation(StartingState,quarantine,socialDistancing)
    averageDays+=days
    dayWithMaxInfectionRate+=Infected.idxmax()
    maxInfection += Infected.max()
    averageMaxCapacity += QC_Occupancy.max()
    averageMaxCapacityDay += QC_Occupancy.idxmax()
    averageCasualties += Casualties
    if i == 9:
        QC_Occupancy.plot(legend=True)
        Infected.plot(legend=True)
print('Average number of days before stabilization: ' + str(averageDays/10))
print('Average of the Day with peak Infection ('+str(maxInfection/10)+'): ' + str(dayWithMaxInfectionRate/10))
print('Average Number of Casualties: ' + str(averageCasualties/10))
print('Average of Max Quarantine centre capacity utilized: ' + str(averageMaxCapacity/10))
print('Average of Max Quarantine centre capacity utilized at: ' + str(averageMaxCapacityDay/10))
# Out:
# Average number of days before stabilization: 123.3
# Average of the Day with peak Infection (181.2): 16.4
# Average Number of Casualties: 52.2
# Average of Max Quarantine centre capacity utilized: 95.4
# Average of Max Quarantine centre capacity utilized at: 20.5

# %% [markdown]
# # Scenario 3b. Enforcing Social Distancing Norms; 25% Infection at Start
# StartingState = 25%
#
# Quarantine=True
#
# Social Distancing=True

# %%
StartingState = 0.25
quarantine=True
socialDistancing=True

averageDays = 0
dayWithMaxInfectionRate = 0
maxInfection = 0
averageMaxCapacity = 0
averageCasualties = 0
averageMaxCapacityDay = 0
for i in range(10):
    days, Casualties, QC_Occupancy, Infected = runSimulation(StartingState,quarantine,socialDistancing)
    averageDays+=days
    dayWithMaxInfectionRate+=Infected.idxmax()
    maxInfection += Infected.max()
    averageMaxCapacity += QC_Occupancy.max()
    averageMaxCapacityDay += QC_Occupancy.idxmax()
    averageCasualties += Casualties
    if i == 9:
        QC_Occupancy.plot(legend=True)
        Infected.plot(legend=True)
print('Average number of days before stabilization: ' + str(averageDays/10))
print('Average of the Day with peak Infection ('+str(maxInfection/10)+'): ' + str(dayWithMaxInfectionRate/10))
print('Average Number of Casualties: ' + str(averageCasualties/10))
print('Average of Max Quarantine centre capacity utilized: ' + str(averageMaxCapacity/10))
print('Average of Max Quarantine centre capacity utilized at: ' + str(averageMaxCapacityDay/10))
# Out:
# Average number of days before stabilization: 120.4
# Average of the Day with peak Infection (258.4): 4.1
# Average Number of Casualties: 60.0
# Average of Max Quarantine centre capacity utilized: 100.0
# Average of Max Quarantine centre capacity utilized at: 7.8

# %% [markdown]
# # Scenario 3c. Enforcing Social Distancing Norms; 50% Infection at Start
# StartingState = 50%
#
# Quarantine=True
#
# Social Distancing=True

# %%
StartingState = 0.5
quarantine=True
socialDistancing=True

averageDays = 0
dayWithMaxInfectionRate = 0
maxInfection = 0
averageMaxCapacity = 0
averageCasualties = 0
averageMaxCapacityDay = 0
for i in range(10):
    days, Casualties, QC_Occupancy, Infected = runSimulation(StartingState,quarantine,socialDistancing)
    averageDays+=days
    dayWithMaxInfectionRate+=Infected.idxmax()
    maxInfection += Infected.max()
    averageMaxCapacity += QC_Occupancy.max()
    averageMaxCapacityDay += QC_Occupancy.idxmax()
    averageCasualties += Casualties
    if i == 9:
        QC_Occupancy.plot(legend=True)
        Infected.plot(legend=True)
print('Average number of days before stabilization: ' + str(averageDays/10))
print('Average of the Day with peak Infection ('+str(maxInfection/10)+'): ' + str(dayWithMaxInfectionRate/10))
print('Average Number of Casualties: ' + str(averageCasualties/10))
print('Average of Max Quarantine centre capacity utilized: ' + str(averageMaxCapacity/10))
print('Average of Max Quarantine centre capacity utilized at: ' + str(averageMaxCapacityDay/10))
# Out:
# Average number of days before stabilization: 114.2
# Average of the Day with peak Infection (500.0): 0.0
# Average Number of Casualties: 76.9
# Average of Max Quarantine centre capacity utilized: 100.0
# Average of Max Quarantine centre capacity utilized at: 3.2
